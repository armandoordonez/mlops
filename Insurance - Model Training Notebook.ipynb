# %%
# !py -m pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\personal\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.6.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: jinja2>=1.2 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: requests>=2.27.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: schemdraw>=0.14 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.16)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: scipy<2.0.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (6.3.0)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: numba>=0.55.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: sktime>=0.16.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: xxhash in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: tbats>=1.1.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (1.1.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\personal\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\personal\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in c:\users\personal\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\personal\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\personal\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: pygments in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: matplotlib-inline in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: colorama in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: decorator in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: backcall in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\personal\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\personal\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\personal\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\personal\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\personal\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: wheel in c:\users\personal\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\personal\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\personal\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jupyter_core in c:\users\personal\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\personal\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\personal\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\personal\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\personal\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\personal\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\personal\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.8.10)
# Requirement already satisfied: jupyter-dash>=0.4.2 in c:\users\personal\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in c:\users\personal\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.9.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\personal\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in c:\users\personal\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in c:\users\personal\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\personal\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\personal\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\personal\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\personal\anaconda3\lib\site-packages (from sktime>=0.16.1->pycaret) (1.2.13)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\personal\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\personal\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\personal\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\personal\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\personal\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: nest-asyncio in c:\users\personal\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\personal\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\personal\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\personal\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\personal\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\personal\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\personal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\personal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: retrying in c:\users\personal\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\personal\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\personal\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\personal\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in c:\users\personal\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: click>=5.1 in c:\users\personal\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\personal\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\personal\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\personal\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: nbconvert>=5 in c:\users\personal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\personal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\personal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\personal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\personal\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: testpath in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: bleach in c:\users\personal\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\personal\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\personal\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\personal\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\personal\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\personal\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\personal\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
from pycaret.datasets import get_data
data = get_data('insurance')

# %% [markdown]
# # Experiment 1

# %%
from pycaret.regression import *

# %%
s = setup(data, target = 'charges', session_id = 123)

# %%
lr = create_model('lr')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:05:41
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_cecd1_row10_col0, #T_cecd1_row10_col1, #T_cecd1_row10_col2, #T_cecd1_row10_col3, #T_cecd1_row10_col4, #T_cecd1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cecd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cecd1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cecd1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cecd1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cecd1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cecd1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cecd1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cecd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cecd1_row0_col0" class="data row0 col0" >4222.9616</td>
#       <td id="T_cecd1_row0_col1" class="data row0 col1" >33775764.3432</td>
#       <td id="T_cecd1_row0_col2" class="data row0 col2" >5811.6920</td>
#       <td id="T_cecd1_row0_col3" class="data row0 col3" >0.7983</td>
#       <td id="T_cecd1_row0_col4" class="data row0 col4" >0.4879</td>
#       <td id="T_cecd1_row0_col5" class="data row0 col5" >0.4328</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cecd1_row1_col0" class="data row1 col0" >4522.5819</td>
#       <td id="T_cecd1_row1_col1" class="data row1 col1" >43620030.5192</td>
#       <td id="T_cecd1_row1_col2" class="data row1 col2" >6604.5462</td>
#       <td id="T_cecd1_row1_col3" class="data row1 col3" >0.7464</td>
#       <td id="T_cecd1_row1_col4" class="data row1 col4" >0.5473</td>
#       <td id="T_cecd1_row1_col5" class="data row1 col5" >0.4216</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cecd1_row2_col0" class="data row2 col0" >3853.0378</td>
#       <td id="T_cecd1_row2_col1" class="data row2 col1" >31981107.9602</td>
#       <td id="T_cecd1_row2_col2" class="data row2 col2" >5655.1842</td>
#       <td id="T_cecd1_row2_col3" class="data row2 col3" >0.5951</td>
#       <td id="T_cecd1_row2_col4" class="data row2 col4" >0.7108</td>
#       <td id="T_cecd1_row2_col5" class="data row2 col5" >0.4398</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cecd1_row3_col0" class="data row3 col0" >3707.7705</td>
#       <td id="T_cecd1_row3_col1" class="data row3 col1" >26513348.5760</td>
#       <td id="T_cecd1_row3_col2" class="data row3 col2" >5149.1114</td>
#       <td id="T_cecd1_row3_col3" class="data row3 col3" >0.7786</td>
#       <td id="T_cecd1_row3_col4" class="data row3 col4" >0.4891</td>
#       <td id="T_cecd1_row3_col5" class="data row3 col5" >0.5164</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cecd1_row4_col0" class="data row4 col0" >4484.2122</td>
#       <td id="T_cecd1_row4_col1" class="data row4 col1" >43828444.1000</td>
#       <td id="T_cecd1_row4_col2" class="data row4 col2" >6620.3054</td>
#       <td id="T_cecd1_row4_col3" class="data row4 col3" >0.6740</td>
#       <td id="T_cecd1_row4_col4" class="data row4 col4" >0.5761</td>
#       <td id="T_cecd1_row4_col5" class="data row4 col5" >0.3847</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cecd1_row5_col0" class="data row5 col0" >4113.6222</td>
#       <td id="T_cecd1_row5_col1" class="data row5 col1" >35882341.9810</td>
#       <td id="T_cecd1_row5_col2" class="data row5 col2" >5990.1871</td>
#       <td id="T_cecd1_row5_col3" class="data row5 col3" >0.7692</td>
#       <td id="T_cecd1_row5_col4" class="data row5 col4" >0.5464</td>
#       <td id="T_cecd1_row5_col5" class="data row5 col5" >0.4130</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cecd1_row6_col0" class="data row6 col0" >4098.0868</td>
#       <td id="T_cecd1_row6_col1" class="data row6 col1" >39631320.0598</td>
#       <td id="T_cecd1_row6_col2" class="data row6 col2" >6295.3411</td>
#       <td id="T_cecd1_row6_col3" class="data row6 col3" >0.7303</td>
#       <td id="T_cecd1_row6_col4" class="data row6 col4" >0.5745</td>
#       <td id="T_cecd1_row6_col5" class="data row6 col5" >0.4266</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cecd1_row7_col0" class="data row7 col0" >4833.7747</td>
#       <td id="T_cecd1_row7_col1" class="data row7 col1" >45739275.7172</td>
#       <td id="T_cecd1_row7_col2" class="data row7 col2" >6763.0818</td>
#       <td id="T_cecd1_row7_col3" class="data row7 col3" >0.7485</td>
#       <td id="T_cecd1_row7_col4" class="data row7 col4" >0.5887</td>
#       <td id="T_cecd1_row7_col5" class="data row7 col5" >0.3967</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cecd1_row8_col0" class="data row8 col0" >4621.0616</td>
#       <td id="T_cecd1_row8_col1" class="data row8 col1" >40681916.3737</td>
#       <td id="T_cecd1_row8_col2" class="data row8 col2" >6378.2377</td>
#       <td id="T_cecd1_row8_col3" class="data row8 col3" >0.7372</td>
#       <td id="T_cecd1_row8_col4" class="data row8 col4" >0.7032</td>
#       <td id="T_cecd1_row8_col5" class="data row8 col5" >0.5225</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cecd1_row9_col0" class="data row9 col0" >4578.4499</td>
#       <td id="T_cecd1_row9_col1" class="data row9 col1" >42227034.9476</td>
#       <td id="T_cecd1_row9_col2" class="data row9 col2" >6498.2332</td>
#       <td id="T_cecd1_row9_col3" class="data row9 col3" >0.7280</td>
#       <td id="T_cecd1_row9_col4" class="data row9 col4" >0.7252</td>
#       <td id="T_cecd1_row9_col5" class="data row9 col5" >0.4793</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cecd1_row10_col0" class="data row10 col0" >4303.5559</td>
#       <td id="T_cecd1_row10_col1" class="data row10 col1" >38388058.4578</td>
#       <td id="T_cecd1_row10_col2" class="data row10 col2" >6176.5920</td>
#       <td id="T_cecd1_row10_col3" class="data row10 col3" >0.7306</td>
#       <td id="T_cecd1_row10_col4" class="data row10 col4" >0.5949</td>
#       <td id="T_cecd1_row10_col5" class="data row10 col5" >0.4433</td>
#     </tr>
#     <tr>
#       <th id="T_cecd1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cecd1_row11_col0" class="data row11 col0" >343.6324</td>
#       <td id="T_cecd1_row11_col1" class="data row11 col1" >5849500.5628</td>
#       <td id="T_cecd1_row11_col2" class="data row11 col2" >487.6160</td>
#       <td id="T_cecd1_row11_col3" class="data row11 col3" >0.0553</td>
#       <td id="T_cecd1_row11_col4" class="data row11 col4" >0.0838</td>
#       <td id="T_cecd1_row11_col5" class="data row11 col5" >0.0451</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(lr)

# %% [markdown]
# # Experiment 2

# %%
s2 = setup(data, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True,
           bin_numeric_features= ['age', 'bmi'])

# %%
s2

# %%
lr = create_model('lr')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:06:57
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_0590d_row10_col0, #T_0590d_row10_col1, #T_0590d_row10_col2, #T_0590d_row10_col3, #T_0590d_row10_col4, #T_0590d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0590d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0590d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0590d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0590d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0590d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0590d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0590d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0590d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0590d_row0_col0" class="data row0 col0" >3039.5847</td>
#       <td id="T_0590d_row0_col1" class="data row0 col1" >21720431.4992</td>
#       <td id="T_0590d_row0_col2" class="data row0 col2" >4660.5184</td>
#       <td id="T_0590d_row0_col3" class="data row0 col3" >0.8703</td>
#       <td id="T_0590d_row0_col4" class="data row0 col4" >0.3966</td>
#       <td id="T_0590d_row0_col5" class="data row0 col5" >0.3151</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0590d_row1_col0" class="data row1 col0" >3379.8362</td>
#       <td id="T_0590d_row1_col1" class="data row1 col1" >32751580.5158</td>
#       <td id="T_0590d_row1_col2" class="data row1 col2" >5722.8997</td>
#       <td id="T_0590d_row1_col3" class="data row1 col3" >0.8096</td>
#       <td id="T_0590d_row1_col4" class="data row1 col4" >0.4432</td>
#       <td id="T_0590d_row1_col5" class="data row1 col5" >0.3076</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0590d_row2_col0" class="data row2 col0" >3077.3214</td>
#       <td id="T_0590d_row2_col1" class="data row2 col1" >23089153.6690</td>
#       <td id="T_0590d_row2_col2" class="data row2 col2" >4805.1174</td>
#       <td id="T_0590d_row2_col3" class="data row2 col3" >0.7077</td>
#       <td id="T_0590d_row2_col4" class="data row2 col4" >0.5047</td>
#       <td id="T_0590d_row2_col5" class="data row2 col5" >0.3831</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0590d_row3_col0" class="data row3 col0" >2939.4254</td>
#       <td id="T_0590d_row3_col1" class="data row3 col1" >20596763.2995</td>
#       <td id="T_0590d_row3_col2" class="data row3 col2" >4538.3657</td>
#       <td id="T_0590d_row3_col3" class="data row3 col3" >0.8280</td>
#       <td id="T_0590d_row3_col4" class="data row3 col4" >0.4446</td>
#       <td id="T_0590d_row3_col5" class="data row3 col5" >0.3809</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0590d_row4_col0" class="data row4 col0" >3161.2812</td>
#       <td id="T_0590d_row4_col1" class="data row4 col1" >28205595.5299</td>
#       <td id="T_0590d_row4_col2" class="data row4 col2" >5310.8940</td>
#       <td id="T_0590d_row4_col3" class="data row4 col3" >0.7902</td>
#       <td id="T_0590d_row4_col4" class="data row4 col4" >0.5012</td>
#       <td id="T_0590d_row4_col5" class="data row4 col5" >0.2972</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0590d_row5_col0" class="data row5 col0" >3108.4472</td>
#       <td id="T_0590d_row5_col1" class="data row5 col1" >24106072.5978</td>
#       <td id="T_0590d_row5_col2" class="data row5 col2" >4909.7935</td>
#       <td id="T_0590d_row5_col3" class="data row5 col3" >0.8449</td>
#       <td id="T_0590d_row5_col4" class="data row5 col4" >0.4032</td>
#       <td id="T_0590d_row5_col5" class="data row5 col5" >0.2975</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0590d_row6_col0" class="data row6 col0" >2752.0468</td>
#       <td id="T_0590d_row6_col1" class="data row6 col1" >21509943.3140</td>
#       <td id="T_0590d_row6_col2" class="data row6 col2" >4637.8813</td>
#       <td id="T_0590d_row6_col3" class="data row6 col3" >0.8536</td>
#       <td id="T_0590d_row6_col4" class="data row6 col4" >0.3703</td>
#       <td id="T_0590d_row6_col5" class="data row6 col5" >0.2962</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0590d_row7_col0" class="data row7 col0" >3409.9708</td>
#       <td id="T_0590d_row7_col1" class="data row7 col1" >29714388.8298</td>
#       <td id="T_0590d_row7_col2" class="data row7 col2" >5451.0906</td>
#       <td id="T_0590d_row7_col3" class="data row7 col3" >0.8366</td>
#       <td id="T_0590d_row7_col4" class="data row7 col4" >0.4531</td>
#       <td id="T_0590d_row7_col5" class="data row7 col5" >0.2934</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0590d_row8_col0" class="data row8 col0" >3282.6467</td>
#       <td id="T_0590d_row8_col1" class="data row8 col1" >25176958.7438</td>
#       <td id="T_0590d_row8_col2" class="data row8 col2" >5017.6647</td>
#       <td id="T_0590d_row8_col3" class="data row8 col3" >0.8374</td>
#       <td id="T_0590d_row8_col4" class="data row8 col4" >0.4151</td>
#       <td id="T_0590d_row8_col5" class="data row8 col5" >0.3560</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0590d_row9_col0" class="data row9 col0" >3298.4391</td>
#       <td id="T_0590d_row9_col1" class="data row9 col1" >28619130.1188</td>
#       <td id="T_0590d_row9_col2" class="data row9 col2" >5349.6850</td>
#       <td id="T_0590d_row9_col3" class="data row9 col3" >0.8157</td>
#       <td id="T_0590d_row9_col4" class="data row9 col4" >0.5129</td>
#       <td id="T_0590d_row9_col5" class="data row9 col5" >0.3591</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0590d_row10_col0" class="data row10 col0" >3144.8999</td>
#       <td id="T_0590d_row10_col1" class="data row10 col1" >25549001.8118</td>
#       <td id="T_0590d_row10_col2" class="data row10 col2" >5040.3910</td>
#       <td id="T_0590d_row10_col3" class="data row10 col3" >0.8194</td>
#       <td id="T_0590d_row10_col4" class="data row10 col4" >0.4445</td>
#       <td id="T_0590d_row10_col5" class="data row10 col5" >0.3286</td>
#     </tr>
#     <tr>
#       <th id="T_0590d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0590d_row11_col0" class="data row11 col0" >195.4008</td>
#       <td id="T_0590d_row11_col1" class="data row11 col1" >3866247.4199</td>
#       <td id="T_0590d_row11_col2" class="data row11 col2" >378.7611</td>
#       <td id="T_0590d_row11_col3" class="data row11 col3" >0.0431</td>
#       <td id="T_0590d_row11_col4" class="data row11 col4" >0.0469</td>
#       <td id="T_0590d_row11_col5" class="data row11 col5" >0.0350</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_model(lr)

# %%
save_model(lr, 'deployment_AI_11_04_23')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\Personal\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   Transform...
#                                                                use_cat_names=True))),
#                  ('polynomial_features',
#                   TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                  ('bin_numeric_features',
#                   TransformerWrapper(include=['age', 'bmi'],
#                                      transformer=KBinsDiscretizer(encode='ordinal',
#                                                                   strategy='kmeans'))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('trained_model', LinearRegression(n_jobs=-1))]),
#  'deployment_AI_11_04_23.pkl')

# %%
deployment_AI_11_04_23 = load_model('deployment_AI_11_04_23')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
deployment_AI_11_04_23
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\Personal\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['age', 'bmi', 'children'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  Transform...
#                                                               use_cat_names=True))),
#                 ('polynomial_features',
#                  TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                 ('bin_numeric_features',
#                  TransformerWrapper(include=['age', 'bmi'],
#                                     transformer=KBinsDiscretizer(encode='ordinal',
#                                                                  strategy='kmeans'))),
#                 ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                 ('trained_model', LinearRegression(n_jobs=-1))])

# %%
import requests
url = 'URl_API'
pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
print(pred.json())
